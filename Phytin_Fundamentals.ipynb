# %% [markdown]
# <a href="https://colab.research.google.com/github/qycorro-glitch/CPE-009A/blob/main/Phytin_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Phyton indentation

# %%
if 5 > 2:
  print("Five is greater than two")
# Out:
# Five is greater than two

# %% [markdown]
# Phyton Comments

# %%
#This is a comment
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# Phyton Variable

# %%
x =1
a, b=0,-1
a, b, c=0, -1, 2

#Others
b = "Sally"#This is a type of string
print (b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b="sally" #This is a type of string
b=int (4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type () Function

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or "Single quotes"

# %%
y = "John"
y = 'John'

# %% [markdown]
# Case Sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z ="four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
 x = "enjoying"
print("Phyton programming is "  +  x )
# Out:
# Phyton programming is enjoying

# %%
#Other way
x ="Phyton is "
y = "enjoying "
z = x + y
print(z)
# Out:
# Phyton is enjoying

# %% [markdown]
# Arithmethic Operations

# %%
x = 6
y = 3
print(x + y)
# Out:
# 9

# %%
x=5
y=3
sum=x+y
sum
# Out:
# 8

# %%
x=5
y=3
print( x - y)
# Out:
# 2

# %%
x=5
y=3
print( x / y)
# Out:
# 1.6666666666666667

# %%
x=5
y=3
print( x % y)
# Out:
# 2

# %%
x=5
y=3
print( x * y)
# Out:
# 15

# %%
x=5
y=3
print ( x ** y)
# Out:
# 125

# %%
x=5
y=3
print( x // y)
# Out:
# 1

# %% [markdown]
# Assignment Operators

# %%
s = 1
s+=3

print(s)
# Out:
# 4

# %%
s = 1
s -= 3

print(s)
# Out:
# -2

# %%
s = 1
s *= 3

print(s)
# Out:
# 3

# %%
s = 1
s /= 3

print(s)
# Out:
# 0.3333333333333333

# %%
s = 1
s %= 3

print(s)
# Out:
# 1

# %%
s = 1
s //= 3

print(s)
# Out:
# 0

# %%
s = 1
s **= 3

print(s)
# Out:
# 1

# %%
s = 1
s &= 3

print(s)
# Out:
# 1

# %%
s = 1
s |= 3

print(s)
# Out:
# 3

# %%
s = 1
s ^= 3

print(s)
# Out:
# 2

# %%
s = 1
s >>= 3

print(s)
# Out:
# 0

# %%
s = 1
s <<= 3

print(s)
# Out:
# 8

# %% [markdown]
# Comparison Operators

# %%
t = 1
u = 2
t == u
# Out:
# False

# %%
t = 1
u = 2
t!=u
# Out:
# True

# %%
t = 1
u = 2
t > u
# Out:
# False

# %%
t = 1
u = 2
t < u
# Out:
# True

# %%
t = 1
u = 2
t >= u
# Out:
# False

# %%
t = 1
u = 2
t <= u
# Out:
# True

# %%
t = 1
u = 2
t == u
t!=u
t > u
t < u
t >= u
t <= u
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
t = 1
u = 2
t < 5 and t < 10
# Out:
# True

# %%
t = 1
u = 2
t < 5 or t < 4
# Out:
# True

# %%
t = 1
u = 2
not(t < 5 and t < 10)
# Out:
# False

# %%
t = 1
u = 2
t < 5 and t < 10
t < 5 or t < 4
not(t < 5 and t < 10)
# Out:
# False

# %% [markdown]
# Identity Operators

# %%
t is u
# Out:
# False

# %%
t is not y
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
V = 2
V << 1
# Out:
# 4

# %%
V = 2
V << 2
# Out:
# 8

# %%
1 & 2
# Out:
# 0

# %%
15 & 15
# Out:
# 15
