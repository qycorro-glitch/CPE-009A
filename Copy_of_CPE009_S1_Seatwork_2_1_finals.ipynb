# %% [markdown]
# <a href="https://colab.research.google.com/github/qycorro-glitch/CPE-009A/blob/main/Copy_of_CPE009_S1_Seatwork_2_1_finals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(actNumber):
      while True:
         inputScore = float(input("Score: "))
         inputTotal = float(input("Total: "))

         if inputScore > inputTotal:
            print("\nInvalid Scores.")
         elif inputScore < 0 or inputTotal <= 0:
            print("\nInvalid Input")
         else:
            rawScore.append(inputScore)
            totalScore.append(inputTotal)
            break

  grade = sum(rawScore) / sum(totalScore)
  grade = grade * 100
  return grade

# %%
def termCS():
  print("Hands-on Activities: ")
  num_hoa = int(input("How many hands-on activities this term? "))
  termHOA = termCrit(num_hoa)

  print("\nQuizzes:")
  num_quiz = int(input("How many quizzes this term? "))
  termQuiz = termCrit(num_quiz)

  print("\nAssignment: ")
  num_ass = int(input("How many assignments? "))
  termAss = termCrit(num_ass)

  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  examGrade = (examRaw/examTotal) * 100

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("\nPrelim Grade")
  prelimGrade = termGrade()

  print("\nMidterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("\nFinal Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  return finalFG

# %%
def convertGrade(finalGrade):
  if finalGrade >= 94.0: return 1.0
  #The class should add everything else
  elif finalGrade >= 90.0: return 1.25
  elif finalGrade >= 87.0: return 1.5
  elif finalGrade >= 84.0: return 1.75
  elif finalGrade >= 80.0: return 2.0
  elif finalGrade >= 77.0: return 2.25
  elif finalGrade >= 74.0: return 2.5
  elif finalGrade >= 71.0: return 2.75
  elif finalGrade >= 68.0: return 3.0
  elif finalGrade >= 65.0: return 3.25
  elif finalGrade >= 62.0: return 3.5
  elif finalGrade >= 59.0: return 3.75
  elif finalGrade >= 56.0: return 4.0
  elif finalGrade >= 53.0: return 4.25
  elif finalGrade >= 50.0: return 4.5
  else: return 5.0
  print("Failed")

# %%
# Driver Code

print("\nTrial 1")
print("Equivalent Grade: ")
convertGrade(semesterGrade())

print("\nTrial 2")
print("Equivalent Grade: ")
convertGrade(semesterGrade())

print("\nTrial 3")
print("Equivalent Grade: ")
convertGrade(semesterGrade())
# Out:
# Trial 1
# Equivalent Grade:
#
# Prelim Grade
# Computing for the term grade.
# Exam Score: 20
# Exam Total: 20
# Hands-on Activities:
# How many hands-on activities this term? 2
# Score: 24
# Total: 24
# Score: 25
# Total: 25
#
# Quizzes:
# How many quizzes this term? 2
# Score: 20
# Total: 20
# Score: 15
# Total: 15
#
# Assignment:
# How many assignments? 2
# Score: 30
# Total: 30
# Score: 25
# Total: 25
#
# Midterm Grade
# Computing for the term grade.
# Exam Score: 30
# Exam Total: 30
# Hands-on Activities:
# How many hands-on activities this term? 2
# Score: 24
# Total: 24
# Score: 25
# Total: 25
#
# Quizzes:
# How many quizzes this term? 2
# Score: 20
# Total: 20
# Score: 25
# Total: 30
#
# Assignment:
# How many assignments? 2
# Score: 25
# Total: 25
# Score: 20
# Total: 20
#
# Final Grade
# Computing for the term grade.
# Exam Score: 50
# Exam Total: 100
# Hands-on Activities:
# How many hands-on activities this term? 2
# Score: 25
# Total: 25
# Score: 20
# Total: 20
#
# ...

# %% [markdown]
# **What is the difference from the code you created?**
#
# the difference is I add some in Driver code and change some syntax in the first column, and arrange the other columns.
#
# <Answer here>
