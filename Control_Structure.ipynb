# %% [markdown]
# <a href="https://colab.research.google.com/github/qycorro-glitch/CPE-009A/blob/main/Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If statement

# %%
a = 12
b = 100
if b>a:
  print("B is greater than a")
# Out:
# B is greater than a

# %% [markdown]
# Elif Statement

# %%
a = 12
b = 12
if b>a:
  print("B is greater than a")
elif a==b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# Else statement

# %%
a = 200
b = 33
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short hand if statement

# %%
if a>b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand if..Else Statement

# %%
a = 2
b = 330
print("A") if a>b else print("B")
# Out:
# B

# %% [markdown]
# And-both conditions are true

# %%
a = 300
b = 33
c = 500
if a>b and c>a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# Or-at least one of the condition is true

# %%
a = 200
b = 33
c = 500
if a>b or a>c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# Nested if

# %%
x = 41

if x > 10:
  print("above ten,")
  if x > 20:
    print("and also above 20")
    if x > 30:
      print("and also above 30")
      if x > 40:
        print("and also above 40")
        if x > 50:
          print("and also above 50")
        else:
          print("below 50")
      else:
        print("below 40")
    else:
      print("below 30")
  else:
    print("below 20")
else:
  print("below 10")
# Out:
# above ten,
# and also above 20
# and also above 30
# and also above 40
# below 50

# %% [markdown]
# EXAMPLE

# %%
2 points

# %%
print("The input number is: ")
a = int(input())

if a <= -1:
    print("The input number is Negative")

elif a == 0:
  print("The Number is Zero")

else:
  print("The Number is Positive")
# Out:
# The input number is:
