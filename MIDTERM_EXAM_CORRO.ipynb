# %% [markdown]
# <a href="https://colab.research.google.com/github/qycorro-glitch/CPE-009A/blob/main/MIDTERM_EXAM_CORRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#23

i = 0
i += 1

while i < 5:
  var = print("*" * i)
  i += 1

else:
  while i >= 0:
    var = print("*" * i)
    i -= 1
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
#24.

#"({[]})" → True"([)]" → False"((()))" → True"({)}" → False

if "({[]})" == true:
  print("True")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_392/2427005147.py in <cell line: 0>()
#       3 #"({[]})" → True"([)]" → False"((()))" → True"({)}" → False
#       4
# ----> 5 if "({[]})" == true:
#       6   print("True")
#       7 else:
#
# NameError: name 'true' is not defined
