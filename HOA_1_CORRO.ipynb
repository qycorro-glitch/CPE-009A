# %% [markdown]
# <a href="https://colab.research.google.com/github/qycorro-glitch/CPE-009A/blob/main/HOA_1_CORRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value = 5
print(value)
# Out:
# 5

# %%
type(value)
# Out:
# int

# %%
value = 5.0
print(value)
# Out:
# 5.0

# %%
type(value)
# Out:
# float

# %% [markdown]
# a.

# %%
value=2+3j
print(value)
# Out:
# (2+3j)

# %%
type(value)
# Out:
# complex

# %% [markdown]
# b

# %%
value='Hello World'
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %% [markdown]
# c.

# %%
value="Hello World"
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %% [markdown]
# d.

# %%
value=True
print(value)
# Out:
# True

# %%
type(value)
# Out:
# bool

# %% [markdown]
# e.

# %%
value=False
print(value)
# Out:
# False

# %%
type(value)
# Out:
# bool

# %% [markdown]
# f.

# %%
value=[1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(value)
# Out:
# list

# %% [markdown]
# g.

# %%
value=(1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
type(value)
# Out:
# tuple

# %% [markdown]
# h.

# %%
value={ 'hashi': 'Yazinel'}
print(value)
# Out:
# {'hashi': 'Yazinel'}

# %%
type(value)
# Out:
# dict

# %% [markdown]
# i.

# %%
value=None
print(value)
# Out:
# None

# %%
type(value)
# Out:
# NoneType

# %% [markdown]
# 2.

# %%
value = 5

# %%
value2 = -6

# %% [markdown]
# Performing Operations with Python

# %%
print(value+value2)
# Out:
# -1

# %%
value, value2 = 5, -6
print(value+value2)
# Out:
# -1

# %% [markdown]
# a.

# %%
 value, value2 = 5.0, 6
 print(value+value2)
# Out:
# 11.0

# %% [markdown]
# B.

# %%
 value, value2 = -5, 6.1
 print(value+value2)
# Out:
# 1.0999999999999996

# %% [markdown]
# C

# %%
value, value2 = "Hello", " world"
print(value+value2)
# Out:
# Hello world

# %% [markdown]
# D

# %%
value, value2 = [1,2,3], [4,5,6]
print(value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# E

# %%
value, value2 = (1,2,3), (4,5,6)
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# F

# %%
 value, value2={"name":"Yazinel"}, {"age":18}

# %%
print(value, value2)
# Out:
# {'name': 'Yazinel'} {'age': 18}

# %% [markdown]
# 3.

# %%
value, value2 = 30, 4

# %%
print(value*value2)
# Out:
# 120

# %%
print(value2**2)
# Out:
# 16

# %%
print(value2**3)
# Out:
# 64

# %%
print(value*value2+value2**2+1)
# Out:
# 137

# %%
print(value/value2)
# Out:
# 7.5

# %%
print(value%value2)
# Out:
# 2

# %% [markdown]
# Tasks

# %%
Base = float(input("Enter Triangle Base: "))
Height = float(input("Enter Triangle Base: "))

Area = (1/2) * Base * Height
print("The Area of Triangle is: ", Area)
# Out:
# Enter Triangle Base: 4
# Enter Triangle Base: 4
# The Area of Triangle is:  8.0

# %% [markdown]
# Assigning Input Data to a Variable

# %%
Name = (input("Enter your name: "))
Weight =  float(input("Enter your weight(kg): "))
Height = float(input( "Enter your meters(m): "))
bmi = Weight / (Height ** 2)
print("Your bmi is: ", bmi)
# Out:
# Enter your name: yazi
# Enter your weight(kg): 50
# Enter your meters(m): 149
# Your bmi is:  0.002252150804017837

# %%
Name = (input("Enter your name: "))
Weight =  float(input("Enter your weight(kg): "))
Height = float(input( "Enter your meters(m): "))
bmi = Weight / (Height ** 2)
print("Your bmi is: ", bmi)

print( " FINAL INFO  ")
print("Name: ", Name)
print("Weight: ", Weight)
print("Height: ", Height)
print("BMI: ", bmi)
# Out:
# Enter your name: John Ray
# Enter your weight(kg): 60
# Enter your meters(m): 1.6764
# Your bmi is:  21.349904958763087
#  FINAL INFO
# Name:  John Ray
# Weight:  60.0
# Height:  1.6764
# BMI:  21.349904958763087

# %% [markdown]
# 2.

# %%
temp = float(input("Enter Temperature in Celcius: "))
far = (temp * 9 /5) + 32
print("Temperature in Fahrenheit: ", far)
# Out:
# Enter Temperature in Celcius: 0
# Temperature in Fahrenheit:  32.0

# %%
temp = float(input("Enter Temperature in Farenheit: "))
cel = (temp - 32) * 5 / 9
print("Temperature in celcius: ", cel)
# Out:
# Enter Temperature in Farenheit: 32
# Temperature in celcius:  0.0
