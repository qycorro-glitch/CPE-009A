# %% [markdown]
# <a href="https://colab.research.google.com/github/qycorro-glitch/CPE-009A/blob/main/Hands_on_Activity_2_1_Literals_and_Variables_(final).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: Hands-on Activity 2.1 Literals and Variables</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming CPE 009| **Date Performed:** Jan 15, 2026 |
# | **Section**: CPE12S2  | **Date Submitted:** Jan 19, 2026|
# | **Student Name**: Yazinel Corro | **Instructor's Name:** Engr. Maria Rizette Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
# 2.   List item
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   Test 3 students from the   program you created.
# 2.   The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
# 3. Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.
# 2.

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25

# %% [markdown]
# Tasks:
# A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:

# %%
PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
Major exams are inputted out of 100%.
Show the codes that successfully run the program.
Provide comments or documentation strings for your program.

# %%
for i in range(3):
  print("\nStudent", i+1)

  Name = (input("Enter your name: "))
  print("Name: ", Name)

  StN = (input("Enter your Student Number: "))
  print("Student Number: ", StN)

  print("\n----PRELIM----")



  a=float(input("Enter your Hands on Activity: "))
  b=float(input("Enter your Quiz score: "))
  c=float(input("Enter your Assignment Score: "))

  a=a* .5
  b=b* .3
  c=c* .2

  d=a+b+c

  print("Prelim CS is: ", d)

  e=float(input("Enter your Prelim Exam Score: "))
  f=float(input("Enter your Prelim Class Standing Score: "))

  e=e* .5
  f=f* .5

  g=e+f

  print("Prelim Grade is: ", g)


  if g >= 75:
    print("Congratutalions you passed your Prelim")
  else:
    print("You failed your Prelim")

  print("\n----MIDTERM----")

  h=float(input("Enter your Hands on Activity: "))
  i=float(input("Enter your Quiz score: "))
  j=float(input("Enter your Assignment Score: "))

  h=h* .5
  i=i* .3
  j=j* .2

  k=h+i+j

  print("Midterm CS is: ", k)

  l=float(input("Enter your Midterm Exam Score: "))
  m=float(input("Enter your Midterm Class Standing Grade: "))

  l=l* .5
  m=m* .5

  n=l+m

  o=g*.33 + n*.67

  print("Midterm Grade is: ", o)

  if o >= 75:
    print("Congratutalions you passed your Midterm")

  else:
    print("You failed your Midterm")

  print("\n----FINALS----")

  p=(float(input("Enter your Hands on Activity: ")))
  q=(float(input("Enter your Quiz score: ")))
  r=(float(input("Enter your Assignment Score: ")))

  p=p*.5
  q=q*.3
  r=r*.2

  s=p+q+r

  print("\nFinal CS is: ", s)

  t=(float(input("Enter your Final Exam Score: ")))
  u=(float(input("Enter your Final Class Standing Grade: ")))

  t=t*.5
  u=u*.5

  v=t+u

  x=o*.33 + v*.67

  print("Final Grade is: ", x)

  if x >= 75:
    print("Congratutalions you passed your Final")

  print("\n----Grade----")
  print("Prelim Grade: ", g)
  print("Midterm Grade: ", o)
  print("Final Grade: ", x)
# Out:
# Student 1
# Enter your name: Yazinel Corro
# Name:  Yazinel Corro
# Enter your Student Number: 895687
# Student Number:  895687
#
# ----PRELIM----
# Enter your Hands on Activity: 89
# Enter your Quiz score: 96
# Enter your Assignment Score: 85
# Prelim CS is:  90.3
# Enter your Prelim Exam Score: 96
# Enter your Prelim Class Standing Score: 90.3
# Prelim Grade is:  93.15
# Congratutalions you passed your Prelim
#
# ----MIDTERM----
# Enter your Hands on Activity: 89
# Enter your Quiz score: 96
# Enter your Assignment Score: 85
# Midterm CS is:  90.3
# Enter your Midterm Exam Score: 96
# Enter your Midterm Class Standing Grade: 90.3
# Midterm Grade is:  93.15
# Congratutalions you passed your Midterm
#
# ----FINALS----
# Enter your Hands on Activity: 89
# Enter your Quiz score: 96
# Enter your Assignment Score: 89
#
# Final CS is:  91.1
# Enter your Final Exam Score: 96
# Enter your Final Class Standing Grade: 91.1
# Final Grade is:  93.418
# Congratutalions you passed your Final
#
# ----Grade----
# Prelim Grade:  93.15
# Midterm Grade:  93.15
# Final Grade:  93.418
#
# Student 2
# Enter your name: Shake
# Name:  Shake
# Enter your Student Number: 676767
# Student Number:  676767
#
# ----PRELIM----
# Enter your Hands on Activity: 89
# Enter your Quiz score: 95
# Enter your Assignment Score: 93
# Prelim CS is:  91.6
# Enter your Prelim Exam Score: 95
# Enter your Prelim Class Standing Score: 91.6
# Prelim Grade is:  93.3
# Congratutalions you passed your Prelim
#
# ----MIDTERM----
# Enter your Hands on Activity: 95
# Enter your Quiz score: 96
# Enter your Assignment Score: 93
# Midterm CS is:  94.9
# Enter your Midterm Exam Score: 95
# Enter your Midterm Class Standing Grade: 94.9
# Midterm Grade is:  94.40550000000002
# Congratutalions you passed your Midterm
#
# ----FINALS----
# Enter your Hands on Activity: 89
# Enter your Quiz score: 96
# Enter your Assignment Score: 95
#
# Final CS is:  92.3
# Enter your Final Exam Score: 96
# Enter your Final Class Standing Grade: 92.3
# Final Grade is:  94.23431500000001
# Congratutalions you passed your Final
#
# ----Grade----
# Prelim Grade:  93.3
# Midterm Grade:  94.40550000000002
# Final Grade:  94.23431500000001
#
# Student 3
# Enter your name: hashi
# Name:  hashi
# Enter your Student Number: 123456
# Student Number:  123456
#
# ----PRELIM----
# Enter your Hands on Activity: 85
# Enter your Quiz score: 96
# Enter your Assignment Score: 93
# Prelim CS is:  89.9
# Enter your Prelim Exam Score: 85
# Enter your Prelim Class Standing Score: 89.9
# Prelim Grade is:  87.45
# Congratutalions you passed your Prelim
#
# ----MIDTERM----
# Enter your Hands on Activity: 85
# Enter your Quiz score: 96
# Enter your Assignment Score: 98
# Midterm CS is:  90.9
# Enter your Midterm Exam Score: 96
# Enter your Midterm Class Standing Grade: 90.9
# Midterm Grade is:  91.47000000000001
# Congratutalions you passed your Midterm
#
# ----FINALS----
# Enter your Hands on Activity: 95
# Enter your Quiz score: 96
# Enter your Assignment Score: 98
#
# Final CS is:  95.9
# Enter your Final Exam Score: 95
# Enter your Final Class Standing Grade: 95.9
# Final Grade is:  94.13660000000002
# Congratutalions you passed your Final
#
# ----Grade----
# Prelim Grade:  87.45
# Midterm Grade:  91.47000000000001
# Final Grade:  94.13660000000002
